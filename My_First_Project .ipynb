# %%
print('Hello')
# Out:
# Hello

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
y = np.array([3,5,7,9])

plt.plot(y, "o-.r", ms = 15, mec = 'g', mfc = 'r')
plt.show()
